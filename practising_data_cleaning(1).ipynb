# %% [markdown]
# <a href="https://colab.research.google.com/github/Mainabryan/Data-Science-Project/blob/main/practising_data_cleaning(1).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # LOAD THE DATASET

# %%
import pandas as pd
gov_dataset = 'http://bit.ly/GovProjectFinanceDataset1'
df = pd.read_csv(gov_dataset)
df.head()
# Out:
#                                  Implementing_Agency  \
# 0                                                NaN
# 1   MOEW&NR  National Environment Management Auth...
# 2   Ministry of Agriculture, Livestock and Fisheries
# 3                                     The Presidency
# 4   MOAL&F  Kenya  Plant Health Inspectorate Serv...
#
#    Total_-_GOK_Budget_Est_KES  Total_-_Loan_Budget_Est_KES  \
# 0                0.000000e+00                            0
# 1                0.000000e+00                            0
# 2                2.306364e+09                  23354779585
# 3                         NaN                            0
# 4                0.000000e+00                            0
#
#    Total_-_Grant_Budget_Est_KES  Total_Budget_Supported__by_Donors_KES  \
# 0                    3524395000                             3524395000
# 1                     300000000                              300000000
# ...

# %% [markdown]
# # HOW TO DEAL WITH MISSING VALUES

# %%
# LEN(DF) -  DF.COUNT()
df_original = df.copy()
len(df) - df.count()
# Out:
# Implementing_Agency                      1
# Total_-_GOK_Budget_Est_KES               1
# Total_-_Loan_Budget_Est_KES              0
# Total_-_Grant_Budget_Est_KES             0
# Total_Budget_Supported__by_Donors_KES    0
# Total_2013/2014_Budget_KES               0
# OBJECTID                                 0
# dtype: int64

# %%
df.isnull().sum()
# Out:
# Implementing_Agency                      1
# Total_-_GOK_Budget_Est_KES               1
# Total_-_Loan_Budget_Est_KES              0
# Total_-_Grant_Budget_Est_KES             0
# Total_Budget_Supported__by_Donors_KES    0
# Total_2013/2014_Budget_KES               0
# OBJECTID                                 0
# dtype: int64

# %%
import numpy as np
np.count_nonzero(df.isnull())
# Out:
# 2

# %% [markdown]
# # step 3  cleaning the missing values

# %%
df.head()
# Out:
#                                  Implementing_Agency  \
# 0                                                NaN
# 1   MOEW&NR  National Environment Management Auth...
# 2   Ministry of Agriculture, Livestock and Fisheries
# 3                                     The Presidency
# 4   MOAL&F  Kenya  Plant Health Inspectorate Serv...
#
#    Total_-_GOK_Budget_Est_KES  Total_-_Loan_Budget_Est_KES  \
# 0                0.000000e+00                            0
# 1                0.000000e+00                            0
# 2                2.306364e+09                  23354779585
# 3                         NaN                            0
# 4                0.000000e+00                            0
#
#    Total_-_Grant_Budget_Est_KES  Total_Budget_Supported__by_Donors_KES  \
# 0                    3524395000                             3524395000
# 1                     300000000                              300000000
# ...

# %% [markdown]
#  1 , through recode
#  2. we can fill_ forward missing values
#
#  3 we can fill backward missing values

# %% [markdown]
# how to recode in data cleaning

# %%
df.recode = df.fillna('unknown')
df.recode.head()
# Out:
#                                  Implementing_Agency  \
# 0                                            unknown
# 1   MOEW&NR  National Environment Management Auth...
# 2   Ministry of Agriculture, Livestock and Fisheries
# 3                                     The Presidency
# 4   MOAL&F  Kenya  Plant Health Inspectorate Serv...
#
#   Total_-_GOK_Budget_Est_KES  Total_-_Loan_Budget_Est_KES  \
# 0                        0.0                            0
# 1                        0.0                            0
# 2               2306364388.0                  23354779585
# 3                    unknown                            0
# 4                        0.0                            0
#
#    Total_-_Grant_Budget_Est_KES  Total_Budget_Supported__by_Donors_KES  \
# 0                    3524395000                             3524395000
# 1                     300000000                              300000000
# 2                    8732081258                            32086860843
# ...

# %%
df_fill_forward = df.fillna(method='ffill')
df.fill.head()
# Out:
# <ipython-input-10-7dc1c9f834d9>:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df_fill_forward = df.fillna(method='ffill')
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-10-7dc1c9f834d9> in <cell line: 0>()
#       1 df_fill_forward = df.fillna(method='ffill')
# ----> 2 df.fill.head()
#       3
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#    6300
#    6301     @final
#
# AttributeError: 'DataFrame' object has no attribute 'fill'

# %%
df_fill_forward = df.fillna(method='ffill')
df_fill_forward.head() # Changed df.fill.head() to df_fill_forward.head()
# Out:
# <ipython-input-11-9a7ab8d8a5f4>:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df_fill_forward = df.fillna(method='ffill')
#                                  Implementing_Agency  \
# 0                                                NaN
# 1   MOEW&NR  National Environment Management Auth...
# 2   Ministry of Agriculture, Livestock and Fisheries
# 3                                     The Presidency
# 4   MOAL&F  Kenya  Plant Health Inspectorate Serv...
#
#    Total_-_GOK_Budget_Est_KES  Total_-_Loan_Budget_Est_KES  \
# 0                0.000000e+00                            0
# 1                0.000000e+00                            0
# 2                2.306364e+09                  23354779585
# 3                2.306364e+09                            0
# 4                0.000000e+00                            0
#
# ...

# %% [markdown]
# in df_fill_forward
# the blank space is replaced by the data that it is behind

# %%
df_fil_backward = df.fillna(method= 'bfill')
df_fil_backward.head()
# Out:
# <ipython-input-13-9cb5a625aa3a>:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df_fil_backward = df.fillna(method= 'bfill')
#                                  Implementing_Agency  \
# 0   MOEW&NR  National Environment Management Auth...
# 1   MOEW&NR  National Environment Management Auth...
# 2   Ministry of Agriculture, Livestock and Fisheries
# 3                                     The Presidency
# 4   MOAL&F  Kenya  Plant Health Inspectorate Serv...
#
#    Total_-_GOK_Budget_Est_KES  Total_-_Loan_Budget_Est_KES  \
# 0                0.000000e+00                            0
# 1                0.000000e+00                            0
# 2                2.306364e+09                  23354779585
# 3                0.000000e+00                            0
# 4                0.000000e+00                            0
#
# ...

# %% [markdown]
# fill missing values using the next valid (non-missing) value found below.

# %% [markdown]
# DROPPING THE DATA

# %%
df.shape
# Out:
# (40, 7)

# %%
df.dropped = df.dropna()
# Out:
# <ipython-input-16-981e3ac00d0a>:1: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   df.dropped = df.dropna()

# %%
df.dropped.shape
# Out:
# (38, 7)

# %%
# these  shows the dataset after dropping it
# Printing out df_dropped
print(df.dropped)
# Out:
#                                   Implementing_Agency  \
# 1    MOEW&NR  National Environment Management Auth...
# 2    Ministry of Agriculture, Livestock and Fisheries
# 4    MOAL&F  Kenya  Plant Health Inspectorate Serv...
# 5                         Ministry of Foreign Affairs
# 6      MRDA  Ewaso Ngiro North Dev. Authority (ENNDA)
# 7    MOE&P  Kenya Electricity Transmission Company...
# 8    Office of The Attorney General and Department...
# 9                  State Department of Infrastructure
# 10                                 Ministry of Health
# 11   MOES&T  Kimathi University of Science and Tec...
# 12                Ministry of Devolution and Planning
# 13   Ministry of Information and Communications an...
# 14    Ministry of Labour Social Security and Services
# 15   Ministry of Commerce Tourism and East African...
# 16   Ministry of Industialization and Enterprise D...
# 17      MRDA Ewaso Ngiro North Dev. Authority (ENNDA)
# ...
